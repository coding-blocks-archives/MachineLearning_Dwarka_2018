# %% [markdown]
# # OpenCV

# %%
import cv2
import matplotlib.pyplot as plt

# %%
im = cv2.imread('/Users/Pratulya/Desktop/space.jpg')
#print(im)
print(type(im))
print(im.shape)
print(im.ndim)
# Out:
# <class 'numpy.ndarray'>
# (1200, 1920, 3)
# 3

# %%
plt.figure()
#plt.imshow(im)

# im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
# plt.imshow(im)

gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
print(im.shape)
print(gray.shape)
plt.imshow(gray, cmap='gray')
# Out:
# (1200, 1920, 3)
# (1200, 1920)

# %%
# cv2.imshow()

# %%
plt.imshow(cv2.resize(im, (100,100)))
